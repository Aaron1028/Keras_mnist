# %%
from keras import backend as K
import keras
from keras.losses import categorical_crossentropy
from keras.optimizers import Adadelta
from keras.datasets import mnist
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

rows, cols = 28, 28
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(x_train.shape[0], rows, cols, 1)
x_test = x_test.reshape(x_test.shape[0], rows, cols, 1)

x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

num_classes = 10
y_test = keras.utils.to_categorical(y_test, num_classes)
y_train = keras.utils.to_categorical(y_train, num_classes)

input_shape = (rows, cols, 1)

batch_size = 120
epochs = 40

model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))

model.add(Conv2D(64, (3, 3), activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=categorical_crossentropy, optimizer='Adadelta', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test)
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/40
# 60000/60000 [==============================] - 99s 2ms/step - loss: 0.3499 - accuracy: 0.8884 - val_loss: 0.0572 - val_accuracy: 0.9813
# Epoch 2/40
# 60000/60000 [==============================] - 95s 2ms/step - loss: 0.1099 - accuracy: 0.9681 - val_loss: 0.0401 - val_accuracy: 0.9869
# Epoch 3/40
# 60000/60000 [==============================] - 96s 2ms/step - loss: 0.0829 - accuracy: 0.9745 - val_loss: 0.0348 - val_accuracy: 0.9887
# Epoch 4/40
# 60000/60000 [==============================] - 95s 2ms/step - loss: 0.0710 - accuracy: 0.9790 - val_loss: 0.0304 - val_accuracy: 0.9893
# Epoch 5/40
# 60000/60000 [==============================] - 96s 2ms/step - loss: 0.0626 - accuracy: 0.9814 - val_loss: 0.0285 - val_accuracy: 0.9913
# Epoch 6/40
# 60000/60000 [==============================] - 96s 2ms/step - loss: 0.0564 - accuracy: 0.9834 - val_loss: 0.0250 - val_accuracy: 0.9921
# Epoch 7/40
# 60000/60000 [==============================] - 96s 2ms/step - loss: 0.0490 - accuracy: 0.9861 - val_loss: 0.0249 - val_accuracy: 0.9924
# Epoch 8/40
# 60000/60000 [==============================] - 94s 2ms/step - loss: 0.0473 - accuracy: 0.9859 - val_loss: 0.0226 - val_accuracy: 0.9929
# Epoch 9/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0445 - accuracy: 0.9870 - val_loss: 0.0227 - val_accuracy: 0.9924
# Epoch 10/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0410 - accuracy: 0.9877 - val_loss: 0.0213 - val_accuracy: 0.9930
# Epoch 11/40
# 60000/60000 [==============================] - 92s 2ms/step - loss: 0.0396 - accuracy: 0.9876 - val_loss: 0.0199 - val_accuracy: 0.9930
# Epoch 12/40
# 60000/60000 [==============================] - 96s 2ms/step - loss: 0.0376 - accuracy: 0.9886 - val_loss: 0.0232 - val_accuracy: 0.9928
# Epoch 13/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0380 - accuracy: 0.9884 - val_loss: 0.0197 - val_accuracy: 0.9932
# Epoch 14/40
# 60000/60000 [==============================] - 95s 2ms/step - loss: 0.0359 - accuracy: 0.9891 - val_loss: 0.0197 - val_accuracy: 0.9940
# Epoch 15/40
# 60000/60000 [==============================] - 95s 2ms/step - loss: 0.0330 - accuracy: 0.9898 - val_loss: 0.0199 - val_accuracy: 0.9931
# Epoch 16/40
# 60000/60000 [==============================] - 95s 2ms/step - loss: 0.0348 - accuracy: 0.9897 - val_loss: 0.0215 - val_accuracy: 0.9935
# Epoch 17/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0343 - accuracy: 0.9903 - val_loss: 0.0189 - val_accuracy: 0.9937
# Epoch 18/40
# 60000/60000 [==============================] - 94s 2ms/step - loss: 0.0334 - accuracy: 0.9901 - val_loss: 0.0202 - val_accuracy: 0.9940
# Epoch 19/40
# 60000/60000 [==============================] - 92s 2ms/step - loss: 0.0324 - accuracy: 0.9906 - val_loss: 0.0180 - val_accuracy: 0.9950
# Epoch 20/40
# 60000/60000 [==============================] - 91s 2ms/step - loss: 0.0323 - accuracy: 0.9906 - val_loss: 0.0199 - val_accuracy: 0.9950
# Epoch 21/40
# 60000/60000 [==============================] - 92s 2ms/step - loss: 0.0327 - accuracy: 0.9900 - val_loss: 0.0202 - val_accuracy: 0.9941
# Epoch 22/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0333 - accuracy: 0.9896 - val_loss: 0.0198 - val_accuracy: 0.9936
# Epoch 23/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0333 - accuracy: 0.9900 - val_loss: 0.0197 - val_accuracy: 0.9944
# Epoch 24/40
# 60000/60000 [==============================] - 94s 2ms/step - loss: 0.0331 - accuracy: 0.9903 - val_loss: 0.0199 - val_accuracy: 0.9942
# Epoch 25/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0322 - accuracy: 0.9907 - val_loss: 0.0211 - val_accuracy: 0.9944
# Epoch 26/40
# 60000/60000 [==============================] - 94s 2ms/step - loss: 0.0324 - accuracy: 0.9908 - val_loss: 0.0212 - val_accuracy: 0.9938
# Epoch 27/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0337 - accuracy: 0.9903 - val_loss: 0.0240 - val_accuracy: 0.9948
# Epoch 28/40
# 60000/60000 [==============================] - 94s 2ms/step - loss: 0.0345 - accuracy: 0.9900 - val_loss: 0.0227 - val_accuracy: 0.9931
# Epoch 29/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0334 - accuracy: 0.9908 - val_loss: 0.0248 - val_accuracy: 0.9936
# Epoch 30/40
# 60000/60000 [==============================] - 91s 2ms/step - loss: 0.0339 - accuracy: 0.9906 - val_loss: 0.0246 - val_accuracy: 0.9940
# Epoch 31/40
# 60000/60000 [==============================] - 91s 2ms/step - loss: 0.0322 - accuracy: 0.9917 - val_loss: 0.0214 - val_accuracy: 0.9946
# Epoch 32/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0334 - accuracy: 0.9911 - val_loss: 0.0275 - val_accuracy: 0.9939
# Epoch 33/40
# 60000/60000 [==============================] - 94s 2ms/step - loss: 0.0345 - accuracy: 0.9909 - val_loss: 0.0224 - val_accuracy: 0.9947
# Epoch 34/40
# 60000/60000 [==============================] - 94s 2ms/step - loss: 0.0333 - accuracy: 0.9905 - val_loss: 0.0201 - val_accuracy: 0.9943
# Epoch 35/40
# 60000/60000 [==============================] - 96s 2ms/step - loss: 0.0336 - accuracy: 0.9912 - val_loss: 0.0239 - val_accuracy: 0.9941
# Epoch 36/40
# 60000/60000 [==============================] - 95s 2ms/step - loss: 0.0372 - accuracy: 0.9906 - val_loss: 0.0212 - val_accuracy: 0.9945
# Epoch 37/40
# 60000/60000 [==============================] - 93s 2ms/step - loss: 0.0346 - accuracy: 0.9909 - val_loss: 0.0300 - val_accuracy: 0.9934
# Epoch 38/40
# 60000/60000 [==============================] - 94s 2ms/step - loss: 0.0355 - accuracy: 0.9908 - val_loss: 0.0229 - val_accuracy: 0.9940
# Epoch 39/40
# 60000/60000 [==============================] - 92s 2ms/step - loss: 0.0334 - accuracy: 0.9910 - val_loss: 0.0208 - val_accuracy: 0.9945
# Epoch 40/40
# 60000/60000 [==============================] - 91s 2ms/step - loss: 0.0324 - accuracy: 0.9916 - val_loss: 0.0242 - val_accuracy: 0.9952
# 10000/10000 [==============================] - 4s 358us/step
# Test accuracy: 0.995199978351593

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 10, 10, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               409728
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 503,690
# Trainable params: 503,690
# Non-trainable params: 0
# _________________________________________________________________
